# %%
import neo4j
from neo4j import GraphDatabase

import pandas

uri = "bolt://localhost:7687"
pwd = "password"

driver = GraphDatabase.driver(uri, auth=("neo4j", pwd))

# %%
# Create Shared PII relationship
query = """
MATCH ( c:Client )-[ :HAS_EMAIL|HAS_PHONE|HAS_SSN ] -> (n) <-[ :HAS_EMAIL|HAS_PHONE|HAS_SSN ]- ( d:Client )
WHERE elementId(c) < elementId(d)
WITH c, d, count(*) AS cnt
MERGE (c) - [ :SHARED_PII { count: cnt } ] -> (d)
"""

with driver.session() as session:
    result = session.run(query)
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# File ~/.local/lib/python3.12/site-packages/neo4j/_async_compat/network/_bolt_socket.py:564, in BoltSocket._connect(cls, resolved_address, timeout, keep_alive)
#     563 log.debug("[#0000]  C: <OPEN> %s", resolved_address)
# --> 564 s.connect(resolved_address)
#     565 s.settimeout(t)
#
# ConnectionRefusedError: [Errno 111] Connection refused
#
# The above exception was the direct cause of the following exception:
#
# ServiceUnavailable                        Traceback (most recent call last)
# File ~/.local/lib/python3.12/site-packages/neo4j/_async_compat/network/_bolt_socket.py:750, in BoltSocket.connect(cls, address, tcp_timeout, deadline, custom_resolver, ssl_context, keep_alive)
#     749 try:
# --> 750     s = BoltSocket._connect(
#     751         resolved_address, tcp_timeout, keep_alive
#     752     )
#     753     s = BoltSocket._secure(
#     754         s, resolved_address._host_name, ssl_context
#     755     )
#
# File ~/.local/lib/python3.12/site-packages/neo4j/_async_compat/network/_bolt_socket.py:586, in BoltSocket._connect(cls, resolved_address, timeout, keep_alive)
#     585 if isinstance(error, OSError):
# --> 586     raise ServiceUnavailable(
#     587         f"Failed to establish connection to {resolved_address!r} "
#     588         f"(reason {error})"
#     589     ) from error
#     590 raise
#
# ServiceUnavailable: Failed to establish connection to ResolvedIPv6Address(('::1', 7687, 0, 0)) (reason [Errno 111] Connection refused)
#
# The above exception was the direct cause of the following exception:
#
# ServiceUnavailable                        Traceback (most recent call last)
# Cell In[2], line 10
#       2 query = """
#       3 MATCH ( c:Client )-[ :HAS_EMAIL|HAS_PHONE|HAS_SSN ] -> (n) <-[ :HAS_EMAIL|HAS_PHONE|HAS_SSN ]- ( d:Client )
#       4 WHERE elementId(c) < elementId(d)
#       5 WITH c, d, count(*) AS cnt
#       6 MERGE (c) - [ :SHARED_PII { count: cnt } ] -> (d)
#       7 """
#       9 with driver.session() as session:
# ---> 10     result = session.run(query)
#
# File ~/.local/lib/python3.12/site-packages/neo4j/_sync/work/session.py:313, in Session.run(self, query, parameters, **kwargs)
#     310     self._auto_result._buffer_all()
#     312 if not self._connection:
# --> 313     self._connect(self._config.default_access_mode)
#     314     assert self._connection is not None
#     315 cx = self._connection
#
# File ~/.local/lib/python3.12/site-packages/neo4j/_sync/work/session.py:136, in Session._connect(self, access_mode, **acquire_kwargs)
#     134     access_mode = self._config.default_access_mode
#     135 try:
# --> 136     super()._connect(
#     137         access_mode, auth=self._config.auth, **acquire_kwargs
#     138     )
#     139 except asyncio.CancelledError:
#     140     self._handle_cancellation(message="_connect")
#
# File ~/.local/lib/python3.12/site-packages/neo4j/_sync/work/workspace.py:184, in Workspace._connect(self, access_mode, auth, **acquire_kwargs)
#     175 acquire_kwargs_ = {
#     176     "access_mode": access_mode,
#     177     "timeout": acquisition_timeout,
#    (...)
#     181     "liveness_check_timeout": None,
#     182 }
#     183 acquire_kwargs_.update(acquire_kwargs)
# --> 184 self._connection = self._pool.acquire(**acquire_kwargs_)
#     185 self._connection_access_mode = access_mode
#
# File ~/.local/lib/python3.12/site-packages/neo4j/_sync/io/_pool.py:597, in BoltPool.acquire(self, access_mode, timeout, database, bookmarks, auth, liveness_check_timeout)
#     590 log.debug(
#     591     "[#0000]  _: <POOL> acquire direct connection, "
#     592     "access_mode=%r, database=%r",
#     593     access_mode,
#     594     database,
#     595 )
#     596 deadline = Deadline.from_timeout_or_deadline(timeout)
# --> 597 return self._acquire(
#     598     self.address, auth, deadline, liveness_check_timeout
#     599 )
#
# File ~/.local/lib/python3.12/site-packages/neo4j/_sync/io/_pool.py:347, in IOPool._acquire(self, address, auth, deadline, liveness_check_timeout)
#     342             raise ClientError(
#     343                 "failed to obtain a connection from the pool within "
#     344                 f"{deadline.original_timeout!r}s (timeout)"
#     345             )
#     346 log.debug("[#0000]  _: <POOL> trying to hand out new connection")
# --> 347 return connection_creator()
#
# File ~/.local/lib/python3.12/site-packages/neo4j/_sync/io/_pool.py:169, in IOPool._acquire_new_later.<locals>.connection_creator()
#     167 try:
#     168     try:
# --> 169         connection = self.opener(
#     170             address, auth or self.pool_config.auth, deadline
#     171         )
#     172     except ServiceUnavailable:
#     173         self.deactivate(address)
#
# File ~/.local/lib/python3.12/site-packages/neo4j/_sync/io/_pool.py:560, in BoltPool.open.<locals>.opener(addr, auth_manager, deadline)
#     559 def opener(addr, auth_manager, deadline):
# --> 560     return Bolt.open(
#     561         addr,
#     562         auth_manager=auth_manager,
#     563         deadline=deadline,
#     564         routing_context=None,
#     565         pool_config=pool_config,
#     566     )
#
# File ~/.local/lib/python3.12/site-packages/neo4j/_sync/io/_bolt.py:448, in Bolt.open(cls, address, auth_manager, deadline, routing_context, pool_config)
#     445 if deadline is None:
#     446     deadline = Deadline(None)
# --> 448 s, protocol_version, handshake, data = BoltSocket.connect(
#     449     address,
#     450     tcp_timeout=pool_config.connection_timeout,
#     451     deadline=deadline,
#     452     custom_resolver=pool_config.resolver,
#     453     ssl_context=pool_config.get_ssl_context(),
#     454     keep_alive=pool_config.keep_alive,
#     455 )
#     457 pool_config.protocol_version = protocol_version
#     459 # Carry out Bolt subclass imports locally to avoid circular dependency
#     460 # issues.
#     461
#     462 # avoid new lines after imports for better readability and conciseness
#     463 # fmt: off
#
# File ~/.local/lib/python3.12/site-packages/neo4j/_async_compat/network/_bolt_socket.py:784, in BoltSocket.connect(cls, address, tcp_timeout, deadline, custom_resolver, ssl_context, keep_alive)
#     782 resolved_address_strs = tuple(map(str, resolved_addresses))
#     783 error_strs = "\n".join(map(str, errors))
# --> 784 raise ServiceUnavailable(
#     785     f"Couldn't connect to {address} "
#     786     f"(resolved to {resolved_address_strs}):\n"
#     787     f"{error_strs}"
#     788 ) from errors[0]
#
# ServiceUnavailable: Couldn't connect to localhost:7687 (resolved to ()):
# Failed to establish connection to ResolvedIPv6Address(('::1', 7687, 0, 0)) (reason [Errno 111] Connection refused)
# Failed to establish connection to ResolvedIPv4Address(('127.0.0.1', 7687)) (reason [Errno 111] Connection refused)

# %%
# Create graph projection
query = """
CALL gds.graph.project(
    'clientClusters' ,
    { 
        Client: { label: 'Client' }
    },
    { 
        SHARED_PII: {
            type: 'SHARED_PII',
            orientation: 'UNDIRECTED',
            properties: { count: { property: 'count' }}
        }
    }
)
YIELD graphName, nodeCount, relationshipCount
"""

with driver.session() as session:
    result = session.run(query)

# %%
query = """
CALL gds.wcc.stream(
    'clientClusters', 
    {
        nodeLabels: ['Client'],
        relationshipTypes: ['SHARED_PII'],
        consecutiveIds: true
    }
) 
YIELD nodeId, componentId
WITH gds.util.asNode(nodeId) AS clientId, componentId AS clusterId
WITH clusterId, collect(clientId.id) AS clients
WITH clusterId, clients, size(clients) AS clusterSize where clusterSize >= 2
    UNWIND clients AS client
    MATCH (c:Client) WHERE c.id = client
    SET c.secondPartyFraudRing = clusterId
"""

with driver.session() as session: 
    result = session.run(query)

# %%
query = """
CALL gds.graph.project(
    'similarity',
    ['Client', 'Email', 'Phone', 'SSN'],
    {
        HAS_EMAIL: {},
        HAS_PHONE: {},
        HAS_SSN: {}
    }
)
YIELD graphName, nodeCount, relationshipCount
WITH graphName, nodeCount, relationshipCount
RETURN graphName, nodeCount, relationshipCount
"""

with driver.session() as session: 
    result = session.run(query)
    print(result.values())
# Out:
# [['similarity', 9134, 7299]]

# %%
# 

query = """
CALL gds.nodeSimilarity.mutate('similarity', { mutateProperty: 'jaccardScore',
mutateRelationshipType: 'SIMILAR_TO' ,
topK: 15
})
"""

with driver.session() as session: 
    result = session.run(query)

# %%
# Write `SIMILAR_TO` to `jaccardScore` 

query = """
CALL gds.graph.relationship.write('similarity', 'SIMILAR_TO', 'jaccardScore', {}) YIELD graphName;
"""

with driver.session() as session: 
    result = session.run(query)

# %%
# Write the similarity to the main graph

query = """
CALL gds.degree.write('similarity', { nodeLabels: ['Client'],
relationshipTypes: ['SIMILAR_TO'],
relationshipWeightProperty: 'jaccardScore',
writeProperty: 'secondPartyFraudScore'
})
"""

with driver.session() as session: 
    result = session.run(query)

# %%
# Add SecondPartyFraudster property if we are very sure

query = """
MATCH (c:Client)
WHERE c.secondPartyFraudScore IS NOT NULL
WITH percentileCont(c.secondPartyFraudScore, 0.95) AS threshold
MATCH (c:Client)
WHERE c.secondPartyFraudScore > threshold
SET c:SecondPartyFraudster
"""

with driver.session() as session: 
    result = session.run(query)

# %%
# Get the name and ID of potential fraudsters

query = """
MATCH (c:Client)
WHERE c:SecondPartyFraudster
RETURN c.name, c.id
"""

panda_df = driver.execute_query(query, database_="neo4j", result_transformer_=neo4j.Result.to_df)

pandas.set_option('display.max_columns', 2)

panda_df
# Out:
#                  c.name              c.id
# 0         Audrey Snider  4446527462545779
# 1            Ayden Mayo  4777446725804270
# 2             Jack Chan  4282733546081412
# 3            Ella Dixon  4536072826730040
# 4     Brooklyn Harrison  4029043591201321
# ..                  ...               ...
# 128       Elijah Warren  4413385955087620
# 129        Xavier Welch  4550448544478545
# 130     Nathaniel Myers  4114683318919154
# 131  Katherine Jacobson  4172817689754167
# 132     Adrian Jacobson  4210575070378533
#
# [133 rows x 2 columns]

# %%
# Drop databases so it can be rerun

query = "CALL gds.graph.drop('clientClusters') YIELD graphName;"

with driver.session() as session:
    result = session.run(query)

query = "CALL gds.graph.drop('similarity') YIELD graphName;"

with driver.session() as session:
    result = session.run(query)
